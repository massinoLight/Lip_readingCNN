# %%
#Import dataset 140Mo
import pathlib
import os
import cv2
import numpy as np
import requests
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import sys
import datetime
from tensorflow import keras
from tensorflow.keras.models import Model
import tensorflow as tf

data_dir = tf.keras.utils.get_file(
    "dataset.zip",
    "https://github.com/massinoLight/Lip_readingCNN/blob/master/lipDataset.zip?raw=true",   
    extract=False)

import zipfile
with zipfile.ZipFile(data_dir, 'r') as zip_ref:
    zip_ref.extractall('./lip/datasets')

data_dir = pathlib.Path('./lip/datasets/dataset')
print(data_dir)
print(os.path.abspath(data_dir))
# Out:
# lip/datasets/dataset
# /Users/massino/Desktop/TensorFlow/lip/datasets/dataset

# %%
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Shape of the image (87102,)
# Shape of the image (568976,)

# %%
#Import dataset 140Mo
import pathlib
import os
data_dir = tf.keras.utils.get_file(
    "lipDataset.zip",
    "https://github.com/massinoLight/Lip_readingCNN/blob/master/lipDataset.zip?raw=true",   
    extract=False)

import zipfile
with zipfile.ZipFile(data_dir, 'r') as zip_ref:
    zip_ref.extractall('./lip/datasets')

data_dir = pathlib.Path('./lip/datasets/dataset')
print(data_dir)
print(os.path.abspath(data_dir))
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-4-693b115e07ab> in <module>
#       8
#       9 import zipfile
# ---> 10 with zipfile.ZipFile(data_dir, 'r') as zip_ref:
#      11     zip_ref.extractall('./lip/datasets')
#      12
#
# ~/opt/anaconda3/lib/python3.8/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1267         try:
#    1268             if mode == 'r':
# -> 1269                 self._RealGetContents()
#    1270             elif mode in ('w', 'x'):
#    1271                 # set the modified flag so central directory gets written
#
# ~/opt/anaconda3/lib/python3.8/zipfile.py in _RealGetContents(self)
#    1334             raise BadZipFile("File is not a zip file")
#    1335         if not endrec:
# -> 1336             raise BadZipFile("File is not a zip file")
# ...
